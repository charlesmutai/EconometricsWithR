# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesmutai/EconometricsWithR/blob/master/Copy_of_R_codes_for_earthquakes_data_in_Example_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
earthquakes <- read.csv("https://raw.githubusercontent.com/charlesmutai/quake/main/quakes.csv")
# earthquakes

# %%
x<-ts(earthquakes$x)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
plot(x,type='o')
# Out:
# plot without title

# %% [markdown]
# ![4-5.png](data:image/png;base64,...)

# %%
install.packages('astsa')
library(astsa)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %%
lag1.plot(x,1)
# Out:
# plot without title

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %%
acf(x,xlim=c(1,19))
# Out:
# Plot with title “Series  x”

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# ![9.png](data:image/png;base64,...)

# %% [markdown]
# ![10.png](data:image/png;base64,...)

# %% [markdown]
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# ![12.png](data:image/png;base64,...)

# %% [markdown]
# ![13.png](data:image/png;base64,...)

# %%
E<-read.csv("https://raw.githubusercontent.com/charlesmutai/quake/main/unemploy.csv")
E
# Out:
#     unemploy
# 1   235.1
# 2   280.7
# 3   264.6
# 4   240.7
# 5   201.4
# 6   240.8
# 7   241.1
# 8   223.8
# 9   206.1
# 10  174.7
# 11  203.3
# 12  220.5
# 13  299.5
# 14  347.4
# 15  338.3
# 16  327.7
# 17  351.6
# 18  396.6
# 19  438.8
# 20  395.6
# 21  363.5
# 22  378.8
# 23  357.0
# 24  369.0
# 25  464.8
# 26  479.1
# 27  431.3
# 28  366.5
# 29  326.3
# 30  355.1
# ⋮   ⋮
# 343 757.7
# 344 732.2
# 345 702.6
# 346 683.3
# 347 709.5
# 348 702.2
# 349 784.8
# 350 810.9
# 351 755.6
# 352 656.8
# 353 615.1
# 354 745.3
# 355 694.1
# 356 675.7
# 357 643.7
# 358 622.1
# 359 634.6
# 360 588.0
# 361 689.7
# 362 673.9
# 363 647.9
# 364 568.8
# 365 545.7
# 366 632.6
# 367 643.8
# 368 593.1
# 369 579.7
# 370 546.0
# 371 562.9
# 372 572.5
